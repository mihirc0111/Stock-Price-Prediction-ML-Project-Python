# %%
import numpy as np 
import pandas as pd 
import os 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
display (os.getcwd())
# Out:
# 'C:\\Users\\HP\\ML acme practice\\Stock Price Prediction Project_python_ml\\PRJ Stock Price Prediction'

# %%
df =pd.read_csv("prices.csv", header=0)
display (df)
# Out:
#                        date symbol        open       close         low  \
# 0       2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1       2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2       2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3       2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4       2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                     ...    ...         ...         ...         ...
# 851259           2016-12-30    ZBH  103.309998  103.199997  102.849998
# 851260           2016-12-30   ZION   43.070000   43.040001   42.689999
# 851261           2016-12-30    ZTS   53.639999   53.529999   53.270000
# 851262  2016-12-30 00:00:00    AIV   44.730000   45.450001   44.410000
# 851263  2016-12-30 00:00:00    FTV   54.200001   53.630001   53.389999
#
#               high     volume
# 0       126.250000  2163600.0
# 1       125.540001  2386400.0
# 2       119.739998  2489500.0
# 3       117.440002  2006300.0
# 4       117.330002  1408600.0
# ...            ...        ...
# 851259  103.930000   973800.0
# 851260   43.310001  1938100.0
# 851261   53.740002  1701200.0
# 851262   45.590000  1380900.0
# 851263   54.480000   705100.0
#
# [851264 rows x 7 columns]

# %%
print(df.shape)
# Out:
# (851264, 7)

# %%
print(df.columns)
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
df.symbol.value_counts()
# Out:
# R       1762
# LMT     1762
# CERN    1762
# CBG     1762
# AGN     1762
#         ...
# PYPL     378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: symbol, Length: 501, dtype: int64

# %%
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
#        'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DLR',
#        'DLTR', 'DNB', 'DOV', 'DOW', 'DPS', 'DRI', 'DTE', 'DUK', 'DVA',
#        'DVN', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR',
#        'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESRX', 'ESS', 'ETFC',
#        'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST',
#        'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR',
#        'FLR', 'FLS', 'FMC', 'FOX', 'FOXA', 'FRT', 'FSLR', 'FTI', 'FTR',
#        'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GOOG', 'GOOGL', 'GPC',
#        'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAR', 'HAS',
#        'HBAN', 'HBI', 'HCN', 'HCP', 'HD', 'HES', 'HIG', 'HOG', 'HOLX',
#        'HON', 'HP', 'HPQ', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY',
#        'HUM', 'IBM', 'ICE', 'IDXX', 'IFF', 'ILMN', 'INTC', 'INTU', 'IP',
#        'IPG', 'IR', 'IRM', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JEC',
#        'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KEY', 'KIM', 'KLAC', 'KMB',
#        'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L', 'LB', 'LEG', 'LEN', 'LH',
#        'LKQ', 'LLL', 'LLTC', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX',
#        'LUK', 'LUV', 'LVLT', 'M', 'MA', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT',
#        'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MHK', 'MJN',
#        'MKC', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MON', 'MOS', 'MRK',
#        'MRO', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MUR', 'MYL', 'NBL',
#        'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE', 'NOC', 'NOV',
#        'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'O', 'OKE',
#        'OMC', 'ORCL', 'ORLY', 'OXY', 'PAYX', 'PBCT', 'PBI', 'PCAR', 'PCG',
#        'PCLN', 'PDCO', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH',
#        'PHM', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL',
#        'PRGO', 'PRU', 'PSA', 'PVH', 'PWR', 'PX', 'PXD', 'QCOM', 'R',
#        'RAI', 'RCL', 'REGN', 'RF', 'RHI', 'RHT', 'RIG', 'RL', 'ROK',
#        'ROP', 'ROST', 'RRC', 'RSG', 'RTN', 'SBUX', 'SCG', 'SCHW', 'SE',
#        'SEE', 'SHW', 'SIG', 'SJM', 'SLB', 'SLG', 'SNA', 'SNI', 'SO',
#        'SPG', 'SPGI', 'SPLS', 'SRCL', 'SRE', 'STI', 'STT', 'STX', 'STZ',
#        'SWK', 'SWKS', 'SWN', 'SYK', 'SYMC', 'SYY', 'T', 'TAP', 'TDC',
#        'TEL', 'TGNA', 'TGT', 'TIF', 'TJX', 'TMK', 'TMO', 'TROW', 'TRV',
#        'TSCO', 'TSN', 'TSO', 'TSS', 'TWX', 'TXN', 'TXT', 'UAA', 'UAL',
#        'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URBN', 'URI',
#        'USB', 'UTX', 'V', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC', 'VNO',
#        'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAT', 'WBA', 'WDC', 'WEC',
#        'WFC', 'WFM', 'WHR', 'WM', 'WMB', 'WMT', 'WU', 'WY', 'WYN', 'WYNN',
#        'XEC', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YHOO', 'YUM',
#        'ZBH', 'ZION', 'AIV', 'CHTR', 'LYB', 'GM', 'ABBV', 'DLPH', 'FB',
#        'FBHS', 'HCA', 'KMI', 'KORS', 'MPC', 'NLSN', 'PSX', 'TDG', 'TRIP',
#        'XYL', 'ZTS', 'COTY', 'MNK', 'NWS', 'NWSA', 'EVHC', 'ALLE', 'CFG',
#        'NAVI', 'QRVO', 'SYF', 'WRK', 'KHC', 'PYPL', 'HPE', 'CSRA', 'FTV'],
#       dtype=object)

# %%
display(df.symbol.unique().shape)
# Out:
# (501,)

# %%
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %%
print(len(df.symbol.values))
# Out:
# 851264

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       70.836986      70.857109      70.118414      71.543476
# std        83.695876      83.689686      82.877294      84.465504
# min         0.850000       0.860000       0.830000       0.880000
# 25%        33.840000      33.849998      33.480000      34.189999
# 50%        52.770000      52.799999      52.230000      53.310001
# 75%        79.879997      79.889999      79.110001      80.610001
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
df.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
df.date.unique()
# Out:
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2016-12-28', '2016-12-29',
#        '2016-12-30'], dtype=object)

# %%
pd.DataFrame(df.date.unique())
# Out:
#                         0
# 0     2016-01-05 00:00:00
# 1     2016-01-06 00:00:00
# 2     2016-01-07 00:00:00
# 3     2016-01-08 00:00:00
# 4     2016-01-11 00:00:00
# ...                   ...
# 3519           2016-12-23
# 3520           2016-12-27
# 3521           2016-12-28
# 3522           2016-12-29
# 3523           2016-12-30
#
# [3524 rows x 1 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Calling the file in nyse named securities.csv, It has the company details 
comp_info = pd.read_csv('securities.csv')
comp_info
# Out:
#     Ticker symbol                Security SEC filings             GICS Sector  \
# 0             MMM              3M Company     reports             Industrials
# 1             ABT     Abbott Laboratories     reports             Health Care
# 2            ABBV                  AbbVie     reports             Health Care
# 3             ACN           Accenture plc     reports  Information Technology
# 4            ATVI     Activision Blizzard     reports  Information Technology
# ..            ...                     ...         ...                     ...
# 500          YHOO              Yahoo Inc.     reports  Information Technology
# 501           YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503          ZION           Zions Bancorp     reports              Financials
# 504           ZTS                  Zoetis     reports             Health Care
#
#                   GICS Sub Industry   Address of Headquarters  \
# 0          Industrial Conglomerates       St. Paul, Minnesota
# 1             Health Care Equipment   North Chicago, Illinois
# 2                   Pharmaceuticals   North Chicago, Illinois
# 3    IT Consulting & Other Services           Dublin, Ireland
# 4       Home Entertainment Software  Santa Monica, California
# ..                              ...                       ...
# 500    Internet Software & Services     Sunnyvale, California
# 501                     Restaurants      Louisville, Kentucky
# 502           Health Care Equipment           Warsaw, Indiana
# 503                  Regional Banks      Salt Lake City, Utah
# 504                 Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK
# 0                NaN    66740
# 1         31-03-1964     1800
# 2         31-12-2012  1551152
# 3         06-07-2011  1467373
# 4         31-08-2015   718877
# ..               ...      ...
# 500              NaN  1011006
# 501       06-10-1997  1041061
# 502              NaN  1136869
# 503              NaN   109380
# 504       21-06-2013  1555280
#
# [505 rows x 8 columns]

# %%
comp_info["Ticker symbol"].nunique()
# Out:
# 505

# %%
comp_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ticker symbol            505 non-null    object
#  1   Security                 505 non-null    object
#  2   SEC filings              505 non-null    object
#  3   GICS Sector              505 non-null    object
#  4   GICS Sub Industry        505 non-null    object
#  5   Address of Headquarters  505 non-null    object
#  6   Date first added         307 non-null    object
#  7   CIK                      505 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.7+ KB

# %%
comp_info.isnull().sum()
# Out:
# Ticker symbol                0
# Security                     0
# SEC filings                  0
# GICS Sector                  0
# GICS Sub Industry            0
# Address of Headquarters      0
# Date first added           198
# CIK                          0
# dtype: int64

# %%
comp_info.describe()
# Out:
#                 CIK
# count  5.050000e+02
# mean   7.074490e+05
# std    5.144375e+05
# min    1.800000e+03
# 25%    8.631200e+04
# 50%    8.310010e+05
# 75%    1.075531e+06
# max    1.659166e+06

# %%
comp_info.loc[comp_info.Security.str.startswith('Face') , :]
# Out:
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK
# 181  1326801

# %%
comp_info.loc[comp_info.Security.str.startswith('Acc') , :]
# Out:
#   Ticker symbol       Security SEC filings             GICS Sector  \
# 3           ACN  Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 3  IT Consulting & Other Services         Dublin, Ireland       06-07-2011
#
#        CIK
# 3  1467373

# %%
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc') 
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"] 
print(comp_plot)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object

# %%
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc') 
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') ] 
display(comp_plot)
# Out:
#     Ticker symbol             Security SEC filings             GICS Sector  \
# 6            ADBE    Adobe Systems Inc     reports  Information Technology
# 181            FB             Facebook     reports  Information Technology
# 212            GS  Goldman Sachs Group     reports              Financials
# 306          MSFT      Microsoft Corp.     reports  Information Technology
# 496           XRX          Xerox Corp.     reports  Information Technology
# 500          YHOO           Yahoo Inc.     reports  Information Technology
#
#                   GICS Sub Industry Address of Headquarters Date first added  \
# 6              Application Software    San Jose, California       05-05-1997
# 181    Internet Software & Services  Menlo Park, California       23-12-2013
# 212  Investment Banking & Brokerage      New York, New York              NaN
# 306                Systems Software     Redmond, Washington       01-06-1994
# 496  IT Consulting & Other Services    Norwalk, Connecticut              NaN
# 500    Internet Software & Services   Sunnyvale, California              NaN
#
#          CIK
# 6     796343
# 181  1326801
# 212   886982
# 306   789019
# 496   108772
# 500  1011006

# %%
for i in comp_plot:
    print (i)
# Out:
# Ticker symbol
# Security
# SEC filings
# GICS Sector
# GICS Sub Industry
# Address of Headquarters
# Date first added
# CIK

# %%
def plotter(code):
    # Function used to create graphs for 6 companies 
    global closing_stock ,opening_stock
    #creating plot of all 6 company for opening and closing stock  total 12 graphs
    # Below statement create 2X2 empty chart 
    f, axs = plt.subplots(2,2,figsize=(15,8))
    # total 12 graphs
    # creating plot opening prize of particular company
    plt.subplot(212)
    #taking name of the company as code, get all records related to one company
    company = df[df['symbol']==code]
    #taking the values of one company and taking its open column values to 1D array
    company = company.open.values.astype('float32')
    #reshaping the open stock value from 1D  to 2D .
    company = company.reshape(-1, 1)
    # putting the value of company in opening_stock 
    opening_stock = company
    # plotting the data with green graph between "Time" and "prices vs time"
    
    plt.grid(True)# enalbling the grid in graph
    plt.xlabel('Time') # setting X axis as time
    # setting Y axis as company name + open stock prices
    plt.ylabel(code + " open stock prices") 
    plt.title('prices Vs Time') # setting title
    plt.plot(company , 'g') # calling the graph with green graph line
    
    # creating plot closing prize of particular company
    plt.subplot(211)
    #taking name of the company as code
    company_close = df[df['symbol']==code]
    #taking the values of one company and taking its close column values
    company_close = company_close.close.values.astype('float32')
    #reshaping the open column value in 1D and calling it closing_stock
   # -1 for unknown dimension
    company_close = company_close.reshape(-1, 1)
    # putting company_close value in closing_stock 
    closing_stock = company_close
    # plotting the data graph between "Time" and "prices vs time"
    plt.xlabel('Time') # setting x axis as time
    plt.ylabel(code + " close stock prices")# setting y axis as company name + open stock prices
    plt.title('prices Vs Time') # setting title as price vs time
    plt.grid(True) # enabling the grid in graph
    plt.plot(company_close , 'b') #creating the data graph in blue graph line
    plt.show() # calling the graph

# %%
for i in comp_plot:
    plotter(i)

# %%
stocks= np.array (df[df.symbol.isin (['YHOO'])].close)
print(stocks)
# Out:
# [17.1      17.23     17.17     ... 38.73     38.639999 38.669998]

# %%
display (stocks.shape)
# Out:
# (1762,)

# %%
stocks = stocks.reshape(len(stocks) , 1)
print (stocks.shape)
print(stocks)
# Out:
# (1762, 1)
# [[17.1     ]
#  [17.23    ]
#  [17.17    ]
#  ...
#  [38.73    ]
#  [38.639999]
#  [38.669998]]

# %%
from sklearn.preprocessing import MinMaxScaler
#scaling features between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1)) 
stocks = scaler.fit_transform(stocks) 
display (stocks)
# Out:
# array([[0.14559109],
#        [0.14874031],
#        [0.14728683],
#        ...,
#        [0.66957366],
#        [0.6673934 ],
#        [0.66812012]])

# %%
print (stocks.shape)
# Out:
# (1762, 1)

# %%
train = int(len(stocks) * 0.80)
print (train)
# Out:
# 1409

# %%
test = len(stocks) - train 
print (test)
# Out:
# 353

# %%
train = stocks[0:train]
display (train.shape)
print(train)
# Out:
# (1409, 1)
# [[0.14559109]
#  [0.14874031]
#  [0.14728683]
#  ...
#  [0.63372095]
#  [0.61458332]
#  [0.61967051]]

# %%
test = stocks[len(train) : ]
display(test.shape)
display (test)
# Out:
# (353, 1)
# array([[0.63129851],
#        [0.60416666],
#        [0.56686053],
#        [0.6017442 ],
#        [0.60925394],
#        [0.60586237],
#        [0.59593022],
#        [0.58381782],
#        [0.55741276],
#        [0.52906978],
#        [0.48982557],
#        [0.50024226],
#        [0.51913761],
#        [0.54748061],
#        [0.53415697],
#        [0.51235471],
#        [0.49685079],
#        [0.500969  ],
#        [0.51962213],
#        [0.49636629],
#        [0.47989342],
#        [0.4949128 ],
#        [0.48594962],
#        [0.49273257],
#        [0.46584303],
#        [0.48328492],
#        [0.49200583],
#        [0.48062017],
#        [0.47601745],
#        [0.48643412],
#        [0.46778102],
#        [0.45179265],
#        [0.44210272],
#        [0.43701549],
#        [0.39995156],
#        [0.41593993],
#        [0.43168606],
#        [0.43168606],
#        [0.47529068],
#        [0.47868218],
#        [0.48134689],
#        [0.50339151],
#        [0.51550386],
#        [0.51913761],
#        [0.52737407],
#        [0.51477714],
#        [0.50872094],
#        [0.54239342],
#        [0.53972867],
#        [0.54287792],
#        [0.52664735],
#        [0.4852229 ],
#        [0.49854652],
#        [0.53488369],
#        [0.54045549],
#        [0.56225774],
#        [0.58381782],
#        [0.58042635],
#        [0.59423449],
#        [0.58575583],
#        [0.57243221],
#        [0.58091087],
#        [0.58212208],
#        [0.55983531],
#        [0.54723839],
#        [0.55474812],
#        [0.53997097],
#        [0.53633722],
#        [0.5111434 ],
#        [0.5295543 ],
#        [0.52737407],
#        [0.53028102],
#        [0.52180236],
#        [0.53343027],
#        [0.53948647],
#        [0.5297965 ],
#        [0.53464149],
#        [0.529312  ],
#        [0.55038763],
#        [0.54796511],
#        [0.5949613 ],
#        [0.56322676],
#        [0.5770349 ],
#        [0.57146319],
#        [0.57558136],
#        [0.56468029],
#        [0.57025198],
#        [0.52858528],
#        [0.52083335],
#        [0.53149224],
#        [0.54966084],
#        [0.53633722],
#        [0.5295543 ],
#        [0.5300388 ],
#        [0.55959301],
#        [0.56589151],
#        [0.55765508],
#        [0.54530035],
#        [0.55595934],
#        [0.53972867],
#        [0.53706392],
#        [0.49200583],
#        [0.5113857 ],
#        [0.51041668],
#        [0.46196707],
#        [0.4733527 ],
#        [0.46220931],
#        [0.47480624],
#        [0.44452523],
#        [0.46584303],
#        [0.43725774],
#        [0.45179265],
#        [0.42853686],
#        [0.44137596],
#        [0.45203489],
#        [0.45276166],
#        [0.4576066 ],
#        [0.45058143],
#        [0.42781009],
#        [0.44622094],
#        [0.44767443],
#        [0.43531975],
#        [0.40188954],
#        [0.43750001],
#        [0.40891471],
#        [0.38662789],
#        [0.38105621],
#        [0.38783916],
#        [0.37960272],
#        [0.38638569],
#        [0.44064926],
#        [0.44282949],
#        [0.44404071],
#        [0.45906011],
#        [0.48643412],
#        [0.47432172],
#        [0.48110469],
#        [0.49103686],
#        [0.49127911],
#        [0.50145352],
#        [0.52592053],
#        [0.52858528],
#        [0.52785856],
#        [0.55159887],
#        [0.55402131],
#        [0.52906978],
#        [0.54312012],
#        [0.52640505],
#        [0.55038763],
#        [0.54481595],
#        [0.53706392],
#        [0.55523252],
#        [0.56177325],
#        [0.5833333 ],
#        [0.59060081],
#        [0.5891473 ],
#        [0.57437014],
#        [0.57582368],
#        [0.58478684],
#        [0.61119188],
#        [0.61700585],
#        [0.62306205],
#        [0.61506784],
#        [0.62814924],
#        [0.61337211],
#        [0.61942831],
#        [0.60755811],
#        [0.60513567],
#        [0.61506784],
#        [0.61942831],
#        [0.63517446],
#        [0.63178291],
#        [0.61579454],
#        [0.61603684],
#        [0.61143417],
#        [0.64801358],
#        [0.64389532],
#        [0.63929265],
#        [0.63323645],
#        [0.6303295 ],
#        [0.62645353],
#        [0.61773257],
#        [0.61797477],
#        [0.61627906],
#        [0.60368214],
#        [0.60343994],
#        [0.62621123],
#        [0.63323645],
#        [0.63202521],
#        [0.63832363],
#        [0.6366279 ],
#        [0.62839146],
#        [0.61506784],
#        [0.63929265],
#        [0.63420544],
#        [0.63347875],
#        [0.62814924],
#        [0.61555234],
#        [0.61942831],
#        [0.64050387],
#        [0.59350777],
#        [0.62185074],
#        [0.64752909],
#        [0.65043604],
#        [0.61918611],
#        [0.63129851],
#        [0.61797477],
#        [0.62936048],
#        [0.62112405],
#        [0.62693802],
#        [0.63614338],
#        [0.62354658],
#        [0.61482562],
#        [0.63735472],
#        [0.63541668],
#        [0.63711239],
#        [0.62621123],
#        [0.63468996],
#        [0.63735472],
#        [0.6363857 ],
#        [0.64656007],
#        [0.60925394],
#        [0.58454461],
#        [0.60440895],
#        [0.6242733 ],
#        [0.64123066],
#        [0.65164735],
#        [0.63977715],
#        [0.64001935],
#        [0.64026164],
#        [0.64559115],
#        [0.65092053],
#        [0.6492248 ],
#        [0.6431686 ],
#        [0.65092053],
#        [0.64510663],
#        [0.65067833],
#        [0.65600772],
#        [0.67369193],
#        [0.67248059],
#        [0.68531981],
#        [0.65964149],
#        [0.67030036],
#        [0.66787792],
#        [0.66448645],
#        [0.65649224],
#        [0.67126937],
#        [0.66569769],
#        [0.6613372 ],
#        [0.67417632],
#        [0.67587216],
#        [0.68192836],
#        [0.68192836],
#        [0.69864343],
#        [0.73110467],
#        [0.77156007],
#        [0.76501935],
#        [0.76065898],
#        [0.76574617],
#        [0.77059115],
#        [0.77349808],
#        [0.76138568],
#        [0.76332361],
#        [0.74660855],
#        [0.7495155 ],
#        [0.75532948],
#        [0.75508718],
#        [0.76283921],
#        [0.76695738],
#        [0.77131785],
#        [0.77979651],
#        [0.81443798],
#        [0.80571703],
#        [0.80595935],
#        [0.77107555],
#        [0.78415697],
#        [0.7739826 ],
#        [0.78415697],
#        [0.79699619],
#        [0.78924416],
#        [0.77761627],
#        [0.7679264 ],
#        [0.80062984],
#        [0.80087216],
#        [0.7681686 ],
#        [0.755814  ],
#        [0.78197674],
#        [0.78972868],
#        [0.76259692],
#        [0.77543602],
#        [0.77616283],
#        [0.77737405],
#        [0.79021317],
#        [0.78948645],
#        [0.77834307],
#        [0.79530036],
#        [0.76526165],
#        [0.75750973],
#        [0.73958333],
#        [0.73522286],
#        [0.74370159],
#        [0.74103684],
#        [0.76647289],
#        [0.75799423],
#        [0.75290695],
#        [0.76308141],
#        [0.7621124 ],
#        [0.75072681],
#        [0.74563953],
#        [0.7434593 ],
#        [0.73788759],
#        [0.73255821],
#        [0.71681203],
#        [0.70591087],
#        [0.70712209],
#        [0.72577519],
#        [0.72843994],
#        [0.72965116],
#        [0.70421513],
#        [0.71051353],
#        [0.68338178],
#        [0.70542635],
#        [0.72407947],
#        [0.73546516],
#        [0.72916666],
#        [0.72722872],
#        [0.72480617],
#        [0.72359495],
#        [0.72141472],
#        [0.73546516],
#        [0.73909881],
#        [0.72504847],
#        [0.69137601],
#        [0.7020349 ],
#        [0.70518415],
#        [0.69961244],
#        [0.71293606],
#        [0.73449614],
#        [0.74297478],
#        [0.73183139],
#        [0.73594965],
#        [0.72238374],
#        [0.66182172],
#        [0.66666671],
#        [0.66206392],
#        [0.67999033],
#        [0.67974813],
#        [0.66400195],
#        [0.66787792],
#        [0.67417632],
#        [0.66957366],
#        [0.6673934 ],
#        [0.66812012]])

# %%
#creating function to create trainX,testX and target(trainY, testY)
def process_data(data , n_features):
    dataX, dataY = [], [] # creating data for dataset and dividing into X,Y
    for i in range(len(data)-n_features):
        # taking i range from total size- 3 
        a = data[i:(i+n_features), 0]
        # Here a is value of data from i to i+ n_features, ie two values and put it in dataX 
        dataX.append(a) #putting a in dataX
        #here dataY takes the value of data of i + n_features
        dataY.append(data[i + n_features, 0])
        # putting i+ n_features in  dataY
    return np.array(dataX), np.array(dataY)
# returning dataX and dataY in array

# %%
n_features = 2
# Here we create train X, Train Y and test X, Test Y data where trainX, testX has two value is each block

trainX, trainY = process_data(train, n_features)
print(trainX.shape , trainY.shape)
# Out:
# (1407, 2) (1407,)

# %%
testX, testY = process_data(test, n_features)
print (testX.shape , testY.shape)
# Out:
# (351, 2) (351,)

# %%
stocksX, stocksY = process_data(stocks, n_features)
print (stocksX.shape , stocksY.shape)
# Out:
# (1760, 2) (1760,)

# %%
display (trainX[:10])
# Out:
# array([[0.14559109, 0.14874031],
#        [0.14874031, 0.14728683],
#        [0.14728683, 0.13590119],
#        [0.13590119, 0.13590119],
#        [0.13590119, 0.13687016],
#        [0.13687016, 0.13541667],
#        [0.13541667, 0.14074613],
#        [0.14074613, 0.14607561],
#        [0.14607561, 0.13880814],
#        [0.13880814, 0.13711241]])

# %%
display (trainY[:10])
# Out:
# array([0.14728683, 0.13590119, 0.13590119, 0.13687016, 0.13541667,
#        0.14074613, 0.14607561, 0.13880814, 0.13711241, 0.1281492 ])

# %%
# reshaping trainX and testX to use in deep learning model
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
display (trainX.shape)
# Out:
# (1407, 1, 2)

# %%
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])
display (testX.shape)
# Out:
# (351, 1, 2)

# %%
stocksX= stocksX.reshape(stocksX.shape[0] , 1 ,stocksX.shape[1])
display (stocksX.shape)
# Out:
# (1760, 1, 2)

# %%
# helps us do mathematical operations
import math 
# for setting layers one by one neural layer in model 
from keras.models import Sequential 
# types of layers
from keras.layers import Dense , BatchNormalization , Dropout , Activation 
# types of RNN
from keras.layers import LSTM , GRU 
#It puts the data in between given range to set data before putting layer
from sklearn.preprocessing import MinMaxScaler 
# In this method the errors in column is squared and then mean is found 
from sklearn.metrics import mean_squared_error 
# Optimizers used
from keras.optimizers import Adam , SGD , RMSprop

# %%
#Checkpointing the model when required and using other call-backs.
filepath="stock_weights1.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
# ReduceLROnPlateau- This reduce the learning rate when the matrix stop improving or  too close to reduce overfitting
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
#This check point will stop processing, if the model is not improving.
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
# creating model for training data using sequential to give series wise output between layers
model = Sequential()
# GRU or Gated Recurrent Unit used for matrix manipulation within Recurrent layer
#This is the input Layer 
model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences=True))
#dropout is used to remove overfitting data on each layer of neural network
model.add(Dropout(0.4))
#Long Short Term Memory is a type of RNN specially used for time series problems
model.add(LSTM(256))
#dropout is used to remove overfitting data on each layer of neural network
model.add(Dropout(0.4))
#Dense layer are fully connected neural networks 
model.add(Dense(64 ,  activation = 'relu'))
#This is the output Layer, Output is only one neuron 
model.add(Dense(1))
#for getting the details of our models
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 256)            199680
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  lstm (LSTM)                 (None, 256)               525312
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 741,505
# Trainable params: 741,505
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Selecting the loss measurement metrics and optimizer for our model, to find out mean square error
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])

# %%
# fitting the data i.e training the trainX, to relate to trainY
# epochs is the times each data in send to fit
# batch size is the size of information send at a time
# validation_data is the validation or data used for testing 
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 , 
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))
# Out:
# Epoch 1/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.1599 - mean_squared_error: 0.1599
# Epoch 1: val_loss improved from -inf to 0.16291, saving model to stock_weights1.hdf5
# 11/11 [==============================] - 3s 62ms/step - loss: 0.1444 - mean_squared_error: 0.1444 - val_loss: 0.1629 - val_mean_squared_error: 0.1629 - lr: 5.0000e-04
# Epoch 2/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0471 - mean_squared_error: 0.0471
# Epoch 2: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - lr: 5.0000e-04
# Epoch 3/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0226 - mean_squared_error: 0.0226
# Epoch 3: val_loss did not improve from 0.16291
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 5.0000e-04
# Epoch 4/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 4: val_loss did not improve from 0.16291
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0044 - val_mean_squared_error: 0.0044 - lr: 5.0000e-05
# Epoch 5/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 5: val_loss did not improve from 0.16291
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0044 - val_mean_squared_error: 0.0044 - lr: 5.0000e-06
# Epoch 6/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 6: val_loss did not improve from 0.16291
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-07
# Epoch 7/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 7: val_loss did not improve from 0.16291
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-08
# Epoch 8/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 8: val_loss did not improve from 0.16291
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-09
# Epoch 9/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 9: val_loss did not improve from 0.16291
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-10
# Epoch 10/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 10: val_loss did not improve from 0.16291
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-11
# Epoch 11/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 11: val_loss did not improve from 0.16291
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-12
# Epoch 12/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 12: val_loss did not improve from 0.16291
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-13
# Epoch 13/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 13: val_loss did not improve from 0.16291
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-14
# Epoch 14/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 14: val_loss did not improve from 0.16291
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-15
# Epoch 15/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 15: val_loss did not improve from 0.16291
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-16
# Epoch 16/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 16: val_loss did not improve from 0.16291
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-17
# Epoch 17/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 17: val_loss did not improve from 0.16291
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-18
# Epoch 18/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 18: val_loss did not improve from 0.16291
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-19
# Epoch 19/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 19: val_loss did not improve from 0.16291
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-20
# Epoch 20/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 20: val_loss did not improve from 0.16291
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-21
# Epoch 21/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 21: val_loss did not improve from 0.16291
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-22
# Epoch 22/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 22: val_loss did not improve from 0.16291
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-23
# Epoch 23/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 23: val_loss did not improve from 0.16291
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-24
# Epoch 24/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 24: val_loss did not improve from 0.16291
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-25
# Epoch 25/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 25: val_loss did not improve from 0.16291
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-26
# Epoch 26/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 26: val_loss did not improve from 0.16291
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-27
# Epoch 27/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 27: val_loss did not improve from 0.16291
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-28
# Epoch 28/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 28: val_loss did not improve from 0.16291
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-29
# Epoch 29/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 29: val_loss did not improve from 0.16291
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-30
# Epoch 30/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 30: val_loss did not improve from 0.16291
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-31
# Epoch 31/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 31: val_loss did not improve from 0.16291
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-32
# Epoch 32/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 32: val_loss did not improve from 0.16291
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-33
# Epoch 33/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 33: val_loss did not improve from 0.16291
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-34
# Epoch 34/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 34: val_loss did not improve from 0.16291
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-35
# Epoch 35/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 35: val_loss did not improve from 0.16291
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-36
# Epoch 36/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 36: val_loss did not improve from 0.16291
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-37
# Epoch 37/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 37: val_loss did not improve from 0.16291
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-38
# Epoch 38/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 38: val_loss did not improve from 0.16291
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-39
# Epoch 39/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 39: val_loss did not improve from 0.16291
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-40
# Epoch 40/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 40: val_loss did not improve from 0.16291
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0000e-41
# Epoch 41/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 41: val_loss did not improve from 0.16291
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 4.9998e-42
# Epoch 42/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 42: val_loss did not improve from 0.16291
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0026e-43
# Epoch 43/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 43: val_loss did not improve from 0.16291
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.0447e-44
# Epoch 44/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 44: val_loss did not improve from 0.16291
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 5.6052e-45
# Epoch 45/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 45: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 46/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 46: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 47/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 47: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 48/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 48: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 49/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 49: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 50/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 50: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 51/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 51: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 52/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 52: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 53/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 53: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 54/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 54: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 55/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 55: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 56/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 56: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 57/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 57: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 58/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 58: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 59/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 59: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 60/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 60: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 61/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 61: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 62/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 62: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 63/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 63: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 64/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 64: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 65/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 65: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 66/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 66: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 67/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 67: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 68/100
#  7/11 [==================>...........] - ETA: 0s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 68: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 69/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 69: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 70/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 70: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 71/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 71: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 72/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 72: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 73/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 73: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 74/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 74: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 75/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 75: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 76/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 76: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 77/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 77: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 78/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 78: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 79/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 79: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 80/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 80: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 81/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 81: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 82/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 82: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 83/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 83: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 84/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 84: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 85/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 85: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 86/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 86: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 87/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 87: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 88/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 88: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 89/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 89: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 90/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 90: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 91/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 91: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 92/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 92: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 93/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 93: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 94/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 94: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 95/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 95: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 96/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 96: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 97/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 97: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 98/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 98: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 99/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 99: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00
# Epoch 100/100
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 100: val_loss did not improve from 0.16291
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0000e+00

# %%
test_pred = model.predict(testX)
display (test_pred [:10])
# Out:
# 11/11 [==============================] - 0s 2ms/step
# array([[0.55853724],
#        [0.5354606 ],
#        [0.53608733],
#        [0.5505595 ],
#        [0.55179715],
#        [0.54693246],
#        [0.5390696 ],
#        [0.5251391 ],
#        [0.5057685 ],
#        [0.48176572]], dtype=float32)

# %%
test_pred = scaler.inverse_transform(test_pred)
display (test_pred [:10])
# Out:
# array([[34.146416],
#        [33.193813],
#        [33.219685],
#        [33.817097],
#        [33.868187],
#        [33.66737 ],
#        [33.342793],
#        [32.767742],
#        [31.968122],
#        [30.97729 ]], dtype=float32)

# %%
testY = testY.reshape(testY.shape[0] , 1)
#Converting reshaped list in 1D array so that it will be efficient in plotting
testY = scaler.inverse_transform(testY)
# taking testY from 1 to 10
display (testY[:10])
# Out:
# array([[34.490002],
#        [35.93    ],
#        [36.240002],
#        [36.099998],
#        [35.689999],
#        [35.189999],
#        [34.099998],
#        [32.93    ],
#        [31.309999],
#        [31.74    ]])

# %%
from sklearn.metrics import r2_score
r2_score(testY,test_pred)
# Out:
# 0.6167450774469178

# %%
# Ploting the graph of stock prices with time
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
# testY is the blue line
plt.plot(testY , 'b')
# pred is the red line
plt.plot(test_pred , 'r')
# Setting x axis as time
plt.xlabel('Time')
# Setting y axis as stock prices
plt.ylabel('Stock Prices')
# setting title 
plt.title('Check the accuracy of the model with time')
# enabling grids in graph 
plt.grid(True)
# it call the graph with labels, titles, lines
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
train_pred = model.predict(trainX)
train_pred = scaler.inverse_transform(train_pred)
trainY = trainY.reshape(trainY.shape[0] , 1)
trainY = scaler.inverse_transform(trainY)
print ('Display Accuracy Training Data')
display (r2_score(trainY,train_pred))
# Out:
# 44/44 [==============================] - 0s 2ms/step
# Display Accuracy Training Data
# 0.8948888624280854

# %%
# Ploting the graph of stock prices with time - Training Data
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(trainY  , 'b')
plt.plot(train_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
stocks_pred = model.predict(stocksX)
stocks_pred = scaler.inverse_transform(stocks_pred)
stocksY = stocksY.reshape(stocksY.shape[0] , 1)
stocksY = scaler.inverse_transform(stocksY)
print ('Display Accuracy Training Data')
display (r2_score(stocksY,stocks_pred))
# Out:
# 55/55 [==============================] - 0s 2ms/step
# Display Accuracy Training Data
# 0.9029166271754532

# %%
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(stocksY  , 'b')
plt.plot(stocks_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()

# %%
# Extract the data related to company - YHOO
results= df[df.symbol.isin (['YHOO'])]
# Update the data frame starting with 2nd records , since first prediction is for 2nd record
results= results [2:]
# Reset the index 0, 1,2 etc
results = results.reset_index(drop=True)
# Convert Predicted Value to Data Frame
df_stocks_pred= pd.DataFrame(stocks_pred, columns = ['Close_Prediction'])
# Concat Original and prediction data
results= pd.concat([results,df_stocks_pred],axis =1)
results.to_excel('results.xlsx')
display(results)
# Out:
#             date symbol       open      close        low       high  \
# 0     2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999
# 1     2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000
# 2     2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000
# 3     2010-01-11   YHOO  16.770000  16.740000  16.480000  16.830000
# 4     2010-01-12   YHOO  16.650000  16.680000  16.600000  16.860001
# ...          ...    ...        ...        ...        ...        ...
# 1755  2016-12-23   YHOO  38.459999  38.660000  38.369999  38.810001
# 1756  2016-12-27   YHOO  38.590000  38.919998  38.500000  39.070000
# 1757  2016-12-28   YHOO  39.119999  38.730000  38.709999  39.220001
# 1758  2016-12-29   YHOO  38.759998  38.639999  38.480000  38.930000
# 1759  2016-12-30   YHOO  38.720001  38.669998  38.430000  39.000000
#
#           volume  Close_Prediction
# 0     16422000.0         20.745237
# 1     31816300.0         20.764994
# 2     15470000.0         20.579559
# 3     16181900.0         20.431442
# 4     15672400.0         20.445597
# ...          ...               ...
# 1755   3840100.0         35.749950
# 1756   4240300.0         35.591602
# 1757   4393500.0         35.743828
# 1758   4170200.0         35.759510
# 1759   6431600.0         35.661476
#
# [1760 rows x 8 columns]

# %%
########################################################

# %%
#Modifications and new data

# %%
#######################################################

# %%
# imports

import numpy as np
import pandas as pd
#from pandas_datareader.data import DataReader
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from IPython import display
import seaborn as sns
# %matplotlib inline

#import functions
import plotting

from datetime import datetime,date

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.metrics import mean_squared_error
#from keras.layers.recurrent import LSTM
from keras.layers import LSTM

# Needed to help our plots look cleaner with plotly 
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# https://towardsdatascience.com/free-stock-data-for-python-using-yahoo-finance-api-9dafd96cad2e
# https://www.learndatasci.com/tutorials/python-finance-part-yahoo-finance-api-pandas-matplotlib/

# Install yfinance
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\hp\anaconda3\lib\site-packages (0.1.74)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (1.2.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: requests>=2.26 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.10)

# %%
# Download stock data then export as CSV

import yfinance as yfin

#tickes are S&P 500, Apple, Microsoft, Amazon, Johnson & Johnson, Pfizer, Ford and Google
tickers = ("SPY", "AAPL", "MSFT", "AMZN", "JNJ", "PFE", "F", "GOOGL") 

start = "2001-01-01"
end = '2021-08-17'

fin_data = yfin.download(tickers, start, end) #download yahoo finance data for specific dates

fin_data.to_csv('fin_data.csv') #convert data to csv
#fin_data.to_csv('finance.csv') #convert data to csv
# Out:
# [*********************100%***********************]  8 of 8 completed

# %%
#check the dimensions of the data
fin_data.shape
# Out:
# (5188, 48)

# %%
#view the first 5 rows of the data
fin_data.head()
# Out:
#            Adj Close                                                   \
#                 AAPL      AMZN          F GOOGL        JNJ       MSFT
# Date
# 2001-01-02  0.226799  0.693750  12.977650   NaN  28.954170  13.602909
# 2001-01-03  0.249670  0.878125  13.411353   NaN  28.031590  15.033761
# 2001-01-04  0.260152  0.775000  14.378837   NaN  27.428398  15.190572
# 2001-01-05  0.249670  0.728125  14.011857   NaN  27.783215  15.406178
# 2001-01-08  0.252529  0.746875  13.678240   NaN  27.747728  15.347377
#
#                                      Close            ...       Open  \
#                   PFE        SPY      AAPL      AMZN  ...        PFE
# Date                                                  ...
# 2001-01-02  20.404381  86.045517  0.265625  0.693750  ...  43.228176
# 2001-01-03  19.270796  90.178680  0.292411  0.878125  ...  43.643265
# 2001-01-04  18.496653  89.208038  0.304688  0.775000  ...  41.627136
# 2001-01-05  18.745487  86.295998  0.292411  0.728125  ...  40.322582
# 2001-01-08  18.524296  86.964005  0.295759  0.746875  ...  40.796963
#
#                           Volume                                       \
#                   SPY       AAPL       AMZN         F GOOGL       JNJ
# Date
# 2001-01-02  132.00000  452312000  184070000   5226500   NaN   8855200
# 2001-01-03  128.31250  817073600  293608000  11157800   NaN  11326000
# 2001-01-04  134.93750  739396000  212410000  14896200   NaN  12941200
# 2001-01-05  133.46875  412356000  175976000   6710900   NaN   9277200
# 2001-01-08  129.87500  373699200  208894000   5900300   NaN   5520200
#
#
#                  MSFT       PFE       SPY
# Date
# 2001-01-02   82413200  11231108   8737500
# 2001-01-03  135962200  23756633  19431600
# 2001-01-04  112397000  34849983   9219000
# 2001-01-05   93414600  19097637  12911400
# 2001-01-08   79817600  14593684   6625300
#
# [5 rows x 48 columns]

# %%
#view the last 5 values of the data
fin_data.tail()
# Out:
#              Adj Close                                                 \
#                   AAPL        AMZN          F       GOOGL         JNJ
# Date
# 2021-08-10  144.788681  166.033997  13.455805  136.807007  168.305099
# 2021-08-11  145.047226  164.605499  13.562907  136.279007  168.334183
# 2021-08-12  148.060349  165.175003  13.533697  137.194000  169.690140
# 2021-08-13  148.269180  164.698502  13.231868  137.727493  170.707138
# 2021-08-16  150.277908  164.949493  13.105293  138.309494  172.247116
#
#                                                     Close              ...  \
#                   MSFT        PFE         SPY        AAPL        AMZN  ...
# Date                                                                   ...
# 2021-08-10  283.518158  46.664616  436.474213  145.600006  166.033997  ...
# 2021-08-11  284.023010  44.844128  437.558807  145.860001  164.605499  ...
# 2021-08-12  286.853821  45.744690  438.870148  148.889999  165.175003  ...
# 2021-08-13  289.862823  46.945438  439.668793  149.100006  164.698502  ...
# 2021-08-16  291.594940  47.361824  440.704071  151.119995  164.949493  ...
#
#                  Open                 Volume                                  \
#                   PFE         SPY       AAPL      AMZN         F       GOOGL
# Date
# 2021-08-10  46.200001  442.609985   69023100  48252000  32120800  19414000.0
# 2021-08-11  47.779999  443.820007   48493500  58944000  42795600  15352000.0
# 2021-08-12  46.500000  443.619995   72282600  46282000  38547900  16506000.0
# 2021-08-13  47.410000  445.589996   59375000  41134000  45118500  15948000.0
# 2021-08-16  48.230000  444.529999  103296000  66394000  38664300  22384000.0
#
#
#                 JNJ      MSFT       PFE       SPY
# Date
# 2021-08-10  3678300  18616600  81189400  43339300
# 2021-08-11  4221300  13955900  50878200  44034300
# 2021-08-12  4300400  14561300  29676400  38909400
# 2021-08-13  5882100  18249000  35379200  39470300
# 2021-08-16  4782800  22507600  38045800  73740000
#
# [5 rows x 48 columns]

# %%
#check if there are missing values for each type of stock
fin_data.isnull().sum()
# Out:
# Adj Close  AAPL       0
#            AMZN       0
#            F          0
#            GOOGL    910
#            JNJ        0
#            MSFT       0
#            PFE        0
#            SPY        0
# Close      AAPL       0
#            AMZN       0
#            F          0
#            GOOGL    910
#            JNJ        0
#            MSFT       0
#            PFE        0
#            SPY        0
# High       AAPL       0
#            AMZN       0
#            F          0
#            GOOGL    910
#            JNJ        0
#            MSFT       0
#            PFE        0
#            SPY        0
# Low        AAPL       0
#            AMZN       0
#            F          0
#            GOOGL    910
#            JNJ        0
#            MSFT       0
#            PFE        0
#            SPY        0
# Open       AAPL       0
#            AMZN       0
#            F          0
#            GOOGL    910
#            JNJ        0
#            MSFT       0
#            PFE        0
#            SPY        0
# Volume     AAPL       0
#            AMZN       0
#            F          0
#            GOOGL    910
#            JNJ        0
#            MSFT       0
#            PFE        0
#            SPY        0
# dtype: int64

# %%
# handing missing values
fin_data.fillna(method='ffill', inplace = True) # use front fill method
fin_data.fillna(method='bfill', inplace = True) # use back fill method

# %%
#check to see if there are still any missing values
fin_data.isnull().sum()
# Out:
# Adj Close  AAPL     0
#            AMZN     0
#            F        0
#            GOOGL    0
#            JNJ      0
#            MSFT     0
#            PFE      0
#            SPY      0
# Close      AAPL     0
#            AMZN     0
#            F        0
#            GOOGL    0
#            JNJ      0
#            MSFT     0
#            PFE      0
#            SPY      0
# High       AAPL     0
#            AMZN     0
#            F        0
#            GOOGL    0
#            JNJ      0
#            MSFT     0
#            PFE      0
#            SPY      0
# Low        AAPL     0
#            AMZN     0
#            F        0
#            GOOGL    0
#            JNJ      0
#            MSFT     0
#            PFE      0
#            SPY      0
# Open       AAPL     0
#            AMZN     0
#            F        0
#            GOOGL    0
#            JNJ      0
#            MSFT     0
#            PFE      0
#            SPY      0
# Volume     AAPL     0
#            AMZN     0
#            F        0
#            GOOGL    0
#            JNJ      0
#            MSFT     0
#            PFE      0
#            SPY      0
# dtype: int64

# %%
#view descriptive statistics of adjusted close process of the stocks
fin_data[['Adj Close']].describe()
# Out:
#          Adj Close                                                      \
#               AAPL         AMZN            F        GOOGL          JNJ
# count  5188.000000  5188.000000  5188.000000  5188.000000  5188.000000
# mean     21.778631    28.895866     8.149963    25.906021    67.276426
# std      30.290362    43.199287     2.770242    25.775237    37.979504
# min       0.200041     0.298500     0.831613     2.502753    23.711021
# 25%       1.974867     2.182125     5.997843     8.554242    38.339007
# 50%      10.538572     9.117500     8.477169    14.865115    46.375984
# 75%      27.351089    36.005000     9.999290    38.405125    96.956089
# max     150.277908   186.570496    16.569674   138.309494   172.247116
#
#
#               MSFT          PFE          SPY
# count  5188.000000  5188.000000  5188.000000
# mean     49.635870    19.264861   148.111715
# std      56.353720     8.227750    85.806457
# min      11.436999     6.703482    52.410133
# 25%      18.859439    12.708109    84.881723
# 50%      22.417095    16.627398   107.972176
# 75%      50.022044    25.157909   187.976208
# max     291.594940    47.361824   440.704071

# %%
# view general info
fin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5188 entries, 2001-01-02 to 2021-08-16
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, AAPL)   5188 non-null   float64
#  1   (Adj Close, AMZN)   5188 non-null   float64
#  2   (Adj Close, F)      5188 non-null   float64
#  3   (Adj Close, GOOGL)  5188 non-null   float64
#  4   (Adj Close, JNJ)    5188 non-null   float64
#  5   (Adj Close, MSFT)   5188 non-null   float64
#  6   (Adj Close, PFE)    5188 non-null   float64
#  7   (Adj Close, SPY)    5188 non-null   float64
#  8   (Close, AAPL)       5188 non-null   float64
#  9   (Close, AMZN)       5188 non-null   float64
#  10  (Close, F)          5188 non-null   float64
#  11  (Close, GOOGL)      5188 non-null   float64
#  12  (Close, JNJ)        5188 non-null   float64
#  13  (Close, MSFT)       5188 non-null   float64
#  14  (Close, PFE)        5188 non-null   float64
#  15  (Close, SPY)        5188 non-null   float64
#  16  (High, AAPL)        5188 non-null   float64
#  17  (High, AMZN)        5188 non-null   float64
#  18  (High, F)           5188 non-null   float64
#  19  (High, GOOGL)       5188 non-null   float64
#  20  (High, JNJ)         5188 non-null   float64
#  21  (High, MSFT)        5188 non-null   float64
#  22  (High, PFE)         5188 non-null   float64
#  23  (High, SPY)         5188 non-null   float64
#  24  (Low, AAPL)         5188 non-null   float64
#  25  (Low, AMZN)         5188 non-null   float64
#  26  (Low, F)            5188 non-null   float64
#  27  (Low, GOOGL)        5188 non-null   float64
#  28  (Low, JNJ)          5188 non-null   float64
#  29  (Low, MSFT)         5188 non-null   float64
#  30  (Low, PFE)          5188 non-null   float64
#  31  (Low, SPY)          5188 non-null   float64
#  32  (Open, AAPL)        5188 non-null   float64
#  33  (Open, AMZN)        5188 non-null   float64
#  34  (Open, F)           5188 non-null   float64
#  35  (Open, GOOGL)       5188 non-null   float64
#  36  (Open, JNJ)         5188 non-null   float64
#  37  (Open, MSFT)        5188 non-null   float64
#  38  (Open, PFE)         5188 non-null   float64
#  39  (Open, SPY)         5188 non-null   float64
#  40  (Volume, AAPL)      5188 non-null   int64
#  41  (Volume, AMZN)      5188 non-null   int64
#  42  (Volume, F)         5188 non-null   int64
#  43  (Volume, GOOGL)     5188 non-null   float64
#  44  (Volume, JNJ)       5188 non-null   int64
#  45  (Volume, MSFT)      5188 non-null   int64
#  46  (Volume, PFE)       5188 non-null   int64
#  47  (Volume, SPY)       5188 non-null   int64
# dtypes: float64(41), int64(7)
# memory usage: 1.9 MB

# %%
# View the maximum close date of stocks
def max_close(stocks,df):
    """ This calculates and returns the maximum closing value of a specific stock"""
    return df['Close'][stocks].max() # computes and returns the maximum closing stock value

# %%
# test the above function with specific stocks
def test_max():
    """ This tests the max_close function"""
    for stocks in ["SPY", "AAPL", "MSFT", "AMZN", "JNJ", "PFE", "F", "GOOGL"]:
        print("Maxiumum Closing Value for {} is {}".format(stocks, max_close(stocks,fin_data)))

test_max()        
#if __name__ == "__main__" :
#    test_()
# Out:
# Maxiumum Closing Value for SPY is 446.9700012207031
# Maxiumum Closing Value for AAPL is 151.1199951171875
# Maxiumum Closing Value for MSFT is 294.6000061035156
# Maxiumum Closing Value for AMZN is 186.57049560546875
# Maxiumum Closing Value for JNJ is 177.83999633789062
# Maxiumum Closing Value for PFE is 48.90999984741211
# Maxiumum Closing Value for F is 30.709999084472656
# Maxiumum Closing Value for GOOGL is 138.3094940185547

# %%
# calculate the mean volume for the stocks
def mean_vol(stocks,df):
    """ This calculates and returns the minimum volume of a specific stock"""
    return df['Volume'][stocks].mean() # computes and returns the minimum volume of a stock

# %%
# test the above function with specific stocks
def test_mean():
    """ This tests the max_close function"""
    for stocks in ["SPY", "AAPL", "MSFT", "AMZN", "JNJ", "PFE", "F", "GOOGL"]:
        print("Mean Volume for {} is {}".format(stocks, mean_vol(stocks,fin_data)))

test_mean()
# Out:
# Mean Volume for SPY is 115524101.9853508
# Mean Volume for AAPL is 433155843.7162683
# Mean Volume for MSFT is 52421931.14880493
# Mean Volume for AMZN is 125479954.12490362
# Mean Volume for JNJ is 9222071.588280648
# Mean Volume for PFE is 33343778.725134928
# Mean Volume for F is 41955511.25674634
# Mean Volume for GOOGL is 265783347.95605242

# %%
#Plotting stock prices

# %%
# Plot function for the Adjusted closing value
def plot_adj(df,title,stocks,y=0):
        ax = df['Adj Close'][stocks].plot(title=title, figsize=(16,8), ax=None)
        ax.set_xlabel("Date")
        ax.set_ylabel("Stock Price")
        ax.axhline(y=y,color='black')
        ax.legend(stocks, loc='upper left')
        plt.show()

# %%
# View the plot of Adjusted close
stocks = ["SPY", "AAPL", "MSFT", "AMZN", "JNJ", "PFE", "F", "GOOGL"]
plot_adj(fin_data,"Adjusted Close Stock Prices",stocks)

# %%
#From the plot above, we can see that Amazon and Google has the highest growth. 
#This could be as a result of the increase in useage of these companies world wide, but let us normalize the data before we make that conclusion. 
#I will explore more features in the dataset before normalizing it.

# %%
# Plot function for the High prices
def plot_high(df,title,stocks,y=0):
        ax = df['High'][stocks].plot(title=title, figsize=(16,8), ax = None)
        ax.set_xlabel("Date")
        ax.set_ylabel("Stock Price")
        ax.axhline(y=y,color='black')
        ax.legend(stocks, loc='upper left')
        plt.show()

# %%
# View the plot of high stock prices
stocks = ["SPY", "AAPL", "MSFT", "AMZN", "JNJ", "PFE", "F", "GOOGL"]
title = "High Stock Prices"
plot_high(fin_data,title,stocks)

# %%
#view only google Adjusted close price
fin_data['Adj Close']['GOOGL']
# Out:
# Date
# 2001-01-02      2.511011
# 2001-01-03      2.511011
# 2001-01-04      2.511011
# 2001-01-05      2.511011
# 2001-01-08      2.511011
#                  ...
# 2021-08-10    136.807007
# 2021-08-11    136.279007
# 2021-08-12    137.194000
# 2021-08-13    137.727493
# 2021-08-16    138.309494
# Name: GOOGL, Length: 5188, dtype: float64

# %%
# view only google and amazon Adjusted close price
fin_data['Adj Close'][['GOOGL', 'AMZN']]
# Out:
#                  GOOGL        AMZN
# Date
# 2001-01-02    2.511011    0.693750
# 2001-01-03    2.511011    0.878125
# 2001-01-04    2.511011    0.775000
# 2001-01-05    2.511011    0.728125
# 2001-01-08    2.511011    0.746875
# ...                ...         ...
# 2021-08-10  136.807007  166.033997
# 2021-08-11  136.279007  164.605499
# 2021-08-12  137.194000  165.175003
# 2021-08-13  137.727493  164.698502
# 2021-08-16  138.309494  164.949493
#
# [5188 rows x 2 columns]

# %%
# view all stocks adjusted close prices for amazon and google from Jan 2010 to Aug 2021
fin_data['Adj Close'].loc['2010-01-01':'2021-08-17', ['AMZN', 'GOOGL']]
# Out:
#                   AMZN       GOOGL
# Date
# 2010-01-04    6.695000   15.684434
# 2010-01-05    6.734500   15.615365
# 2010-01-06    6.612500   15.221722
# 2010-01-07    6.500000   14.867367
# 2010-01-08    6.676000   15.065566
# ...                ...         ...
# 2021-08-10  166.033997  136.807007
# 2021-08-11  164.605499  136.279007
# 2021-08-12  165.175003  137.194000
# 2021-08-13  164.698502  137.727493
# 2021-08-16  164.949493  138.309494
#
# [2925 rows x 2 columns]

# %%
# view all stocks adjusted close price from Jan 2010 to Aug 2021
fin_data['Adj Close'].loc['2010-01-01':'2021-08-17']
# Out:
#                   AAPL        AMZN          F       GOOGL         JNJ  \
# Date
# 2010-01-04    6.526019    6.695000   6.784907   15.684434   44.564320
# 2010-01-05    6.537303    6.734500   7.233714   15.615365   44.047585
# 2010-01-06    6.433318    6.612500   7.504317   15.221722   44.405857
# 2010-01-07    6.421427    6.500000   7.695721   14.867367   44.088917
# 2010-01-08    6.464118    6.676000   7.715522   15.065566   44.240486
# ...                ...         ...        ...         ...         ...
# 2021-08-10  144.788681  166.033997  13.455805  136.807007  168.305099
# 2021-08-11  145.047226  164.605499  13.562907  136.279007  168.334183
# 2021-08-12  148.060349  165.175003  13.533697  137.194000  169.690140
# 2021-08-13  148.269180  164.698502  13.231868  137.727493  170.707138
# 2021-08-16  150.277908  164.949493  13.105293  138.309494  172.247116
#
#                   MSFT        PFE         SPY
# Date
# 2010-01-04   23.749815  11.223427   89.225380
# 2010-01-05   23.757486  11.063351   89.461609
# 2010-01-06   23.611689  11.027773   89.524574
# 2010-01-07   23.366135  10.986271   89.902496
# 2010-01-08   23.527273  11.075205   90.201645
# ...                ...        ...         ...
# 2021-08-10  283.518158  46.664616  436.474213
# 2021-08-11  284.023010  44.844128  437.558807
# 2021-08-12  286.853821  45.744690  438.870148
# 2021-08-13  289.862823  46.945438  439.668793
# 2021-08-16  291.594940  47.361824  440.704071
#
# [2925 rows x 8 columns]

# %%
# create function to plot data
def plot_data1(df,stocks,title,ylabel='Stock Price',y=0):
    """This funtion plots stock prices"""
    ax = df.plot(title=title, figsize=(16,8), ax=None, fontsize=2)
    ax.set_xlabel("Date")
    ax.set_label(ylabel)
    ax.axhline(y=y,color='black')
    ax.legend(stocks, loc='upper left')
    plt.show()

# %%
# create function to plot selected stocks
def selected_plot(df, columns,stocks, start_idx, end_idx):
    """This function plots specific stocks over a given date range"""
    plot_data1(df[columns].loc[start_idx:end_idx, stocks],stocks, title="Plot for selected Stocks")

# %%
# create function to plot data based on specific columns, symbols, and date ranges
def test_select():
    """This function plots stock data based on specific columns, symbols, and date ranges """
    # specify columns to plot and stock symbols
    columns = 'Adj Close'
    stocks = ['GOOGL', 'AMZN']  
        
    # Get stock data
    df = fin_data

    # Slice and plot
    selected_plot(df, columns, stocks, '2010-01-01', '2021-08-17')
    
test_select()  # run the plot function

# %%
#Normalizing the data
#We want to know how the different types of stocks went up and down with respect to the others. 
#In order to do this, we will normalize the data. We do this by dividing the values of each column 
#by day one to ensure that each stock starts with $1 .

# %%
def plot_data2(df,stocks,title='Stock Prices',ylabel="Stock Price",y=0, start='2001-01-01', end ='2021-08-17'):
    
    """ This function creates a plot of adjusted close stock prices
    inputs:
    df - dataframe
    title - plot title
    stocks - the stock symbols of each company
    ylabel - y axis label
    y - horizontal line(integer)
    output: the plot of adjusted close stock prices
    """
    df_new = df[start:end]
    #ax = df_new['Adj Close'][stocks].plot(title=title, figsize=(16,8), ax = None)
    ax = df_new.plot(title=title, figsize=(16,8), ax = None)
    ax.set_xlabel("Date")
    ax.set_ylabel(ylabel)
    ax.axhline(y=y,color='black')
    ax.legend(stocks, loc='upper left')
    plt.show()

# %%
# create function that normalizes the data
def normalize_data(df):
    """ 
    This function normalizes the stock prices using the first row of the dataframe
    input - stock data
    output - normalized stock data
    """
    return df/df.iloc[0,:]

# %%
# plot the data with the new normalized data

stocks = ["SPY", "AAPL", "MSFT", "AMZN", "JNJ", "PFE", "F", "GOOGL"]

plot_data2(normalize_data(fin_data['Adj Close'][stocks]),stocks,title = "Normalized Stock Prices", ylabel = 'Cummulative return',y=1)

# %%
#From the above cummulative return plot, we can see that Apple has the highest return over the years, while Amazon was second and Google third and Microsoft fourth. The growth of Google and Microsoft looks much more stable than Apple and Amazon. Looking at the plot, Apple has alot of volatility and risky stocks especially in recent years.

# %%
#Cumulative Return
#Let's have a look at how the pandemic affected stock prices for these companies.

# %%
stocks = ["SPY", "AAPL", "MSFT", "AMZN", "JNJ", "PFE", "F", "GOOGL"]

plot_data2(normalize_data(fin_data['Adj Close'][stocks]['2019-01-01':'2019-12-31']), stocks,title = '2019', ylabel = 'Cummulative return',y=1, start='2019-01-01', end = '2019-12-31') #2019
plot_data2(normalize_data(fin_data['Adj Close'][stocks]['2020-01-01':'2020-12-31']), stocks,title = '2020', ylabel = 'Cummulative return',y=1, start='2020-01-01', end = '2020-12-31') #2020
plot_data2(normalize_data(fin_data['Adj Close'][stocks]['2021-01-01':'2021-08-17']), stocks,title = '2021', ylabel = 'Cummulative return',y=1, start='2021-01-01', end = '2021-08-17') #2021

# %%
#Computing the Rolling mean and Bollinger Bands

# %%
#The rolling mean may give us some idea about the true underlying prices of a stock. If there is a significant deviation below or above the rolling mean, it may give us an idea about a potential buying and selling opportunity respectively.

# %%
# Bollinger observed that looking at the recent volatility of the stock, if it is very volatile, we might discard the movement above and below the mean. But if it is not very volatile we may want to pay attention to it.

# %%
# compute rolling mean, rolling standard deviation, upper and lower bands

def rolling_stats(df, stocks, type_, window = 20):
    """
    This function computes the rolling mean and Bollinger bands
    inputs : 
    df - dataframe
    stocks - the type of stocks we would be analyzing
    type_ - the price type of the rolling calculation
    window - number of days used to calculate the statistics
    output: 
    rolling mean, rolling standard deviation, upper and lower bands of 2 std each
    """
    
    val = df[(type_,stocks)]
    rolling_mean = df[(type_, stocks)].rolling(window=window).mean()
    rolling_std = df[(type_, stocks)].rolling(window=window).std()
    upper_band = rolling_mean + rolling_std*2
    lower_band = rolling_mean - rolling_std*2
    
    return val, rolling_mean, rolling_std, upper_band, lower_band

# %%
# plot the rolling mean, rolling standard deviation, upper and lower bands

def rolling_plot(stocks, val, rolling_mean, upper_band, lower_band, title='Rolling mean'):
    """
    This function plots the rolling mean and Bollinger bands
    inputs : 
    stocks - the type of stocks we would be analyzing
    val - value of the stock price type
    rolling_mean - rolling mean
    upper_band - stocks upper band
    lower_band - stocks lower band
    title - plot title
    output: 
    plot of rolling mean, rolling standard deviation, upper and lower bands of 2 std each
    """
    
    ax = rolling_mean.plot(title=title, figsize=(16,8), label='Rolling Mean')
    plt.plot(upper_band, label = 'Upper Band')
    plt.plot(lower_band, label = 'Lower Band')
    plt.plot(val, label = 'Value of Stock')
    ax.set_xlabel('Date')
    ax.set_ylabel('Price')
    ax.legend(loc='upper left')
    plt.show()
    
    return ax

# %%
stocks = 'MSFT'
type_ = 'Adj Close'

val, rolling_mean, rolling_std, upper_band, lower_band = rolling_stats(fin_data['2019-01-01':'2021-08-17'], stocks, type_)

rolling_plot(stocks, val, rolling_mean, upper_band, lower_band, title='Rolling mean of {} for {} 20 days window'.format(type_,stocks))
plt.show()

# %%
# view rolling statistics for Apple
stocks = 'AAPL'
type_ = 'Adj Close'

val, rolling_mean, rolling_std, upper_band, lower_band = rolling_stats(fin_data['2019-01-01':'2021-08-17'], stocks, type_)

rolling_plot(stocks, val, rolling_mean, upper_band, lower_band, title='Rolling mean of {} for {} 20 days window'.format(type_,stocks))
plt.show()

# %%
# view rolling statistics for Ford
stocks = 'F'
type_ = 'Adj Close'

val, rolling_mean, rolling_std, upper_band, lower_band = rolling_stats(fin_data['2019-01-01':'2021-08-17'], stocks, type_)

rolling_plot(stocks, val, rolling_mean, upper_band, lower_band, title='Rolling mean of {} for {} 20 days window'.format(type_,stocks))
plt.show()

# %%
#Computing Daily Returns
#Daily returns tells us how much the stock price go up and down on a particular day.

# %%
def daily_returns_cal(df,stocks):
    """
    This function computes and returns the daily return values
    input: df (dataframe) and stocks
    output: daily return values
    """
    
    daily_returns = (df[('Adj Close', stocks)][1:]/df[('Adj Close', stocks)][:-1].values) - 1
       
    return daily_returns

# %%
# Daily return of Microsoft
plot_data2(daily_returns_cal(fin_data,'MSFT'),stocks=['MSFT'], ylabel = 'Daily returns',title='Stock Prices for Microsoft',y=0)

# %%
# Daily return of Ford
plot_data2(daily_returns_cal(fin_data,'F'),stocks=['F'], ylabel = 'Daily returns',title='Stock Prices for Ford',y=0)

# %%
#3. Modelling
#In this section I will be trying out some models to predict the Adjusted closing price of a stock.

# %%
#Predicting Adjusted close value of Microsoft stocks

# %%
# Function that get specific stock data and fills in any missing value
def get_data(df, stocks):
    """
    This function gets a specific stock data and fills in any missing values using the fill forward and fill backward methods
    Input: 
    df - dataframe
    stocks - the type of stock
    Output - a cleaned dataset to be used for prediction
    """
    df1 = pd.DataFrame (data = df.iloc[:, df.columns.get_level_values(1)==stocks].values,
                          index = df.iloc[:, df.columns.get_level_values(1)==stocks].index,
                          columns = df.iloc[:, df.columns.get_level_values(1)==stocks].columns.get_level_values(0))
    
    df1.fillna(method='ffill', inplace= True)
    df1.fillna(method='bfill', inplace=True)
    
    return df1

# %%
# get Microsoft data and view the first 5 rows
msft_data = get_data(fin_data, 'MSFT')  
msft_data.head()
# Out:
#             Adj Close     Close     High       Low      Open       Volume
# Date
# 2001-01-02  13.602909  21.68750  22.5000  21.43750  22.06250   82413200.0
# 2001-01-03  15.033761  23.96875  24.4375  21.56250  21.59375  135962200.0
# 2001-01-04  15.190572  24.21875  25.2500  23.43750  23.90625  112397000.0
# 2001-01-05  15.406178  24.56250  24.9375  23.78125  24.25000   93414600.0
# 2001-01-08  15.347377  24.46875  24.8750  23.34375  24.46875   79817600.0

# %%
# plot showing Microsoft historical Adjusted closing prices
plt.figure(figsize=(16,6))
plt.title('Microsoft Adjusted Close Price History')
plt.plot(msft_data['Adj Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Adjusted Close Price USD ($)', fontsize=18)
plt.show()

# %%
#Predicting using Long Short-Term Memory (LSTM)
#LSTM is an artificial recurrent neural network (RNN) architecture used in deep learning that is capable of learning long-term dependencies. It processes data passing on information as it propagates forward and have a chain like structure.

# %%
#view the shape
msft_data.shape
# Out:
# (5188, 6)

# %%
# create the variables for prediction and split into training and test sets

y = np.log(msft_data['Adj Close'].astype(int)) # we want to predict the adjusted close price
X = msft_data.drop('Adj Close', axis=1) # predictive variables (removing Adj close from it)

#split the data into training and test sets
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Build the LSTM model for Microsoft stock
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (xtrain.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# view model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 5, 128)            66560
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense_2 (Dense)             (None, 25)                1625
#
#  dense_3 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 117,619
# Trainable params: 117,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#Initial parameters used for LSTM

# %%
# Train the model - part 1
model.fit(np.array(xtrain).reshape(-1,5,1), ytrain, batch_size =1, epochs=5, verbose=0)

# %%
#predictions 
predictions = model.predict(np.array(xtest).reshape(-1,5,1))
# Out:
# 33/33 [==============================] - 1s 1ms/step

# %%
#calculation of the mean absolute error
mean_abs_error3 = mean_absolute_error(ytest, predictions)
mean_abs_error3
# Out:
# 0.06734109522916489

# %%
# Train the model - part 2
model.fit(np.array(xtrain).reshape(-1,5,1), ytrain, batch_size =100, epochs=10, verbose=0)

# %%
#predictions 2
predictions = model.predict(np.array(xtest).reshape(-1,5,1))
# Out:
# 33/33 [==============================] - 0s 2ms/step

# %%
#calculation of the mean absolute error 2
mean_abs_error3 = mean_absolute_error(ytest, predictions)
mean_abs_error3
# Out:
# 0.05981360432219187

# %%
#LSTM Refinement
#Final Parameters used to tune LSTM

# %%
# Build the LSTM model with the relu activation function
model2 = Sequential()
model2.add(LSTM(128, activation='relu', return_sequences=True, input_shape= (xtrain.shape[1], 1)))
model2.add(LSTM(64, activation='relu', return_sequences=False))
model2.add(Dense(25))
model2.add(Dense(1))

# %%
# Compile the model
model2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# view model2 summary
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 5, 128)            66560
#
#  lstm_4 (LSTM)               (None, 64)                49408
#
#  dense_4 (Dense)             (None, 25)                1625
#
#  dense_5 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 117,619
# Trainable params: 117,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model - part 3
model2.fit(np.array(xtrain).reshape(-1,5,1), ytrain, batch_size =1, epochs=5, verbose=0)

# %%
#predictions 3
predictions2 = model2.predict(np.array(xtest).reshape(-1,5,1))
# Out:
# 33/33 [==============================] - 0s 1ms/step

# %%
#calculation of the mean absolute error 2
mean_abs_error2 = mean_absolute_error(ytest, predictions)
mean_abs_error2
# Out:
# 0.05981360432219187

# %%
# Train the model - part 4 (increasing no. of epochs and batch_size)
model2.fit(np.array(xtrain).reshape(-1,5,1), ytrain, batch_size =100, epochs=10, verbose=0)

# %%
#predictions 3
predictions2 = model2.predict(np.array(xtest).reshape(-1,5,1))
# Out:
# 33/33 [==============================] - 0s 1ms/step

# %%
#calculation of the mean absolute error 2
mean_abs_error2 = mean_absolute_error(ytest, predictions)
mean_abs_error2
# Out:
# 0.05981360432219187

# %%
#plot showing the prediction and actual values
# import seaborn as sns

# import matplotlib.pyplot as plt
# import numpy as np



fig, axs = plt.subplots(1, 2, figsize=(24, 10), dpi=80)
axs[0].set_title('Predicted vs actual values distribution')
ax1 = sns.kdeplot(data=ytest, color="g", label='Actual values',ax=axs[0])
ax2 = sns.kdeplot(data=predictions2, color="b", label='Predicted values', ax=ax1)
# import warnings 
# warnings.filterwarnings("ignore")
sns.regplot(x=ytest, y=predictions2)
plt.title('Predicted vs actual values distribution')
plt.xlabel('Stock Price')
#plt.legend()
ax1.legend()
plt.show()
plt.close()
    
print("Mean absolute error of {0}: {1}".format(model,mean_abs_error3))
# Out:
# Mean absolute error of <keras.engine.sequential.Sequential object at 0x0000022BD6FA8BE0>: 0.05981360432219187

# %%
# Train the model part 5 (no activation function)
model.fit(np.array(xtrain).reshape(-1,5,1), ytrain, batch_size =800, epochs=50, verbose=0)

# %%
#predictions 
predictions = model.predict(np.array(xtest).reshape(-1,5,1))
# Out:
# 33/33 [==============================] - 0s 2ms/step

# %%
#calculation of the mean absolute error
mean_abs_error3 = mean_absolute_error(ytest, predictions)
mean_abs_error3
# Out:
# 0.05933836530828249

# %%
#plot showing the prediction and actual values

fig, axs = plt.subplots(1, 2, figsize=(24, 10), dpi=80)
axs[0].set_title('Predicted vs actual values distribution')
ax1 = sns.kdeplot(data=ytest, color="g", label='Actual values',ax=axs[0])
ax2 = sns.kdeplot(data=predictions, color="b", label='Predicted values', ax=ax1)
    
sns.regplot(x=ytest, y=predictions)
plt.title('Predicted vs actual values distribution')
plt.xlabel('Stock Price')
#plt.legend()
ax1.legend()
plt.show()
plt.close()
    
print("Mean absolute error of {0}: {1}".format(model,mean_abs_error3))
# Out:
# Mean absolute error of <keras.engine.sequential.Sequential object at 0x0000022BD6FA8BE0>: 0.05933836530828249

# %%
#From the above, we can see that the model is trained and evaluated using LSTM. The predicted and actual adjustable stock prices plots look are relatively similar with a mean absolute error of 0.0598 which isn't bad. However, there is still room for improvement and trying out other models to compare.

# %%
#Predicting using Linear Regression

# %%
#view the shape
msft_data.tail()
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2021-08-10  283.518158  286.440002  289.250000  285.200012  288.799988
# 2021-08-11  284.023010  286.950012  288.660004  285.859985  287.209991
# 2021-08-12  286.853821  289.809998  289.970001  286.339996  286.630005
# 2021-08-13  289.862823  292.850006  292.899994  289.299988  289.480011
# 2021-08-16  291.594940  294.600006  294.820007  290.019989  293.190002
#
#                 Volume
# Date
# 2021-08-10  18616600.0
# 2021-08-11  13955900.0
# 2021-08-12  14561300.0
# 2021-08-13  18249000.0
# 2021-08-16  22507600.0

# %%
# Building the model for Adj close prediction

y = np.log(msft_data['Adj Close'].astype(int)) # we want to predict the adjusted close price
X = msft_data.drop('Adj Close', axis=1) # predictive variables (removing Adj close from it)

#split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("x_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (4150, 5)
# y_train (4150,)
# x_test (1038, 5)
# y_test (1038,)

# %%
#creating an instance of a Linear Regressor 
model_lin = LinearRegression()

#fit the model
model_lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# check the score, coef_ and intercept_ of the model
model_lin.score(X_train,y_train)
model_lin.coef_
model_lin.intercept_

print('The score of the model is {}, the coeficients  are {} and the intercept is {}'.format(model_lin.score(X_train,y_train),model_lin.coef_,model_lin.intercept_))
# Out:
# The score of the model is 0.8941971128083975, the coeficients  are [ 1.58010405e-02  2.38564742e-02 -4.80255851e-02  2.02514622e-02
#  -5.10439722e-09] and the intercept is 3.0493163926006193

# %%
#prediction
predict = model_lin.predict(X_test)
predict #view some predictions
# Out:
# array([3.39407097, 4.71168843, 3.31271052, ..., 3.96591496, 3.47203007,
#        3.44884137])

# %%
#calculation of the mean absolute error
mean_abs_error = mean_absolute_error(y_test, predict)
mean_abs_error
# Out:
# 0.21606034284689224

# %%
#plot showing the prediction and actual values

fig, axs = plt.subplots(1, 2, figsize=(24, 10), dpi=80)
axs[0].set_title('Predicted vs actual values distribution')
ax1 = sns.kdeplot(data=y_test, color="g", label='Actual values',ax=axs[0])
ax2 = sns.kdeplot(data=predict, color="b", label='Predicted values', ax=ax1)
    
sns.regplot(x=y_test, y=predict)
plt.title('Predicted vs actual values distribution')
plt.xlabel('Stock Price')
#plt.legend()
ax1.legend()
plt.show()
plt.close()
    
print("Mean absolute error of {0}: {1}".format(model_lin,mean_abs_error))
# Out:
# Mean absolute error of LinearRegression(): 0.21606034284689224

# %%
#From the above, we can see that the model is trained and evaluated using LinearRegression. The predicted and actual adjustable stock prices plots have variations but with a mean absolute error is 0.216 which abit worst than the LSTM model. However, there is still room for improvement and trying out other models to compare. Let't try out another model and see how it performs.

#Predicting using Random Forest Regressor

# %%
# Building the model for Adj close prediction

y = np.log(msft_data['Adj Close'].astype(int)) # we want to predict the adjusted close price
X = msft_data.drop('Adj Close', axis=1) # predictive variables (removing Adj close from it)

#split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("x_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (4150, 5)
# y_train (4150,)
# x_test (1038, 5)
# y_test (1038,)

# %%
#creating an instance of a Random Forest Regressor 
model_rf = RandomForestRegressor(n_estimators=100, random_state=47)

# %%
#fit the model with the training data
model_rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=47)

# %%
#prediction
predict = model_rf.predict(X_test)
predict #view some predictions
# Out:
# array([3.52636052, 4.88196083, 3.58378521, ..., 4.36040314, 3.70863354,
#        3.70985032])

# %%
#calculation of the mean absolute error
mean_abs_error = mean_absolute_error(y_test, predict)
mean_abs_error
# Out:
# 0.04980518119930469

# %%
# view predictions and actual values
#print(np.c_[y_test,predict])
display_ = pd.DataFrame({'Actual value': y_test, 'Predicted value':predict})
display_.head(10)
#print(y_test,predict)
# Out:
#             Actual value  Predicted value
# Date
# 2014-05-16      3.526361         3.526361
# 2019-07-31      4.875197         4.881961
# 2015-02-03      3.583519         3.583785
# 2002-11-20      2.833213         2.886373
# 2008-02-14      2.995732         3.011619
# 2010-03-04      3.091042         3.059726
# 2015-09-09      3.637586         3.629298
# 2021-07-28      5.645447         5.647084
# 2009-09-25      2.944439         2.911799
# 2001-07-12      3.091042         3.167506

# %%
#From the table, we can see that the RandomForestRegressor performed very well and the actual and predicted Adjusted close value are fairly close. Let us now view the plots.

# %%
#plot showing the prediction and actual values

fig, axs = plt.subplots(1, 2, figsize=(24, 10), dpi=80)
axs[0].set_title('Predicted vs actual values distribution')
ax1 = sns.kdeplot(data=y_test, color="g", label='Actual values',ax=axs[0])
ax2 = sns.kdeplot(data=predict, color="b", label='Predicted values', ax=ax1)
    
sns.regplot(x=y_test, y=predict)
plt.title('Predicted vs actual values distribution')
plt.xlabel('Stock Price')
#plt.legend()
ax1.legend()
plt.show()
plt.close()
    
print("Mean absolute error of {0}: {1}".format(model_rf,mean_abs_error))
# Out:
# Mean absolute error of RandomForestRegressor(random_state=47): 0.04980518119930469

# %%
#From the above, we can see that the model is trained and evaluated using RandomForestRegressor. The predicted and actual adjustable stock prices plots look are relatively similar with a mean absolute error is 0.0498 which is good. Let us see how our three models would perfomr with the Google stocks.

#Predicting Adjusted close value of Google stocks

# %%
# get Google data and view the first 5 rows
googl_data = get_data(fin_data, 'GOOGL')  
googl_data.head()
# Out:
#             Adj Close     Close      High       Low      Open       Volume
# Date
# 2001-01-02   2.511011  2.511011  2.604104  2.401401  2.502503  893181924.0
# 2001-01-03   2.511011  2.511011  2.604104  2.401401  2.502503  893181924.0
# 2001-01-04   2.511011  2.511011  2.604104  2.401401  2.502503  893181924.0
# 2001-01-05   2.511011  2.511011  2.604104  2.401401  2.502503  893181924.0
# 2001-01-08   2.511011  2.511011  2.604104  2.401401  2.502503  893181924.0

# %%
# plot showing Google historical Adjusted closing prices
plt.figure(figsize=(16,6))
plt.title('Google Adjusted Close Price History')
plt.plot(googl_data['Adj Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Adjusted Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Building the model for Adj close prediction

# create the variables for prediction and split into training and test sets

y = np.log(googl_data['Adj Close'].astype(int)) # we want to predict the adjusted close price
X = googl_data.drop('Adj Close', axis=1) # predictive variables (removing Adj close from it)

#split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("x_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (4150, 5)
# y_train (4150,)
# x_test (1038, 5)
# y_test (1038,)

# %%
#Prediction Using LSTM

# %%
#### LSTM Model for Google stocks

model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (X_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model part 5 (no activation function)
model.fit(np.array(X_train).reshape(-1,5,1), y_train, batch_size =800, epochs=50, verbose=0)

#predictions 
predictions = model.predict(np.array(X_test).reshape(-1,5,1))

#calculation of the mean absolute error
mean_abs_error = mean_absolute_error(y_test, predictions)
mean_abs_error
# Out:
# 33/33 [==============================] - 1s 2ms/step
# 0.01722420779992442

# %%
#Prediction Using Linear Regression

# %%
#creating an instance of a Linear Regressor 
model_lin2 = LinearRegression()

#fit the model
model_lin2.fit(X_train,y_train)

#prediction
predict = model_lin2.predict(X_test)

#calculation of the mean absolute error
mean_abs_error = mean_absolute_error(y_test, predict)
mean_abs_error
# Out:
# 0.17882117290858718

# %%
#Prediction Using Random Forest Regressor
#creating an instance of a Random Forest Regressor 
model_rf2 = RandomForestRegressor(n_estimators=100, random_state=47)

#fit the model with the training data
model_rf2.fit(X_train,y_train)

#prediction
predict2 = model_rf2.predict(X_test)
predict2 #view some predictions

#calculation of the mean absolute error
mean_abs_error2 = mean_absolute_error(y_test, predict2)
mean_abs_error2
# Out:
# 0.0007589002884249367

# %%
#plot showing the prediction and actual values

fig, axs = plt.subplots(1, 2, figsize=(24, 10), dpi=80)
axs[0].set_title('Predicted vs actual values distribution')
ax1 = sns.kdeplot(data=y_test, color="g", label='Actual values',ax=axs[0])
ax2 = sns.kdeplot(data=predict2, color="b", label='Predicted values', ax=ax1)
    
sns.regplot(x=y_test, y=predict2)
plt.title('Predicted vs actual values distribution')
plt.xlabel('Stock Price')
#plt.legend()
ax1.legend()
plt.show()
plt.close()
    
print("Mean absolute error of {0}: {1}".format(model_rf2,mean_abs_error2))
# Out:
# Mean absolute error of RandomForestRegressor(random_state=47): 0.0007589002884249367

# %%
#plot showing the prediction and actual values

fig, axs = plt.subplots(1, 2, figsize=(24, 10), dpi=80)
axs[0].set_title('Actual values distribution')
axs[1].set_title('Predicted values distribution')
ax1 = sns.kdeplot(data=y_test, color="g", label='Actual values',ax=axs[0])
ax2 = sns.kdeplot(data=predict2, color="b", label='Predicted values', ax=axs[1])

ax1.legend()
ax2.legend()
plt.show()
plt.close()
    
print("Mean absolute error of {0}: {1}".format(model_rf2,mean_abs_error2))
# Out:
# Mean absolute error of RandomForestRegressor(random_state=47): 0.0007589002884249367

# %%
#From the above, we can see that the model is trained and evaluated using RandomForestRegressor. The predicted and actual adjustable Google stock prices plots look are very similar with a mean absolute error is 0.000758 which is very good. We can also see that all three models perform better with Google than Microsoft stocks.

# %%
# Results
# Evaluation and Validation of models
# From my investigation of three different models, I observed that RandomForestRegressor delivered a much lower mean absolute error  than the LSTM  or LinearRegression  for Microsoft and Google respectively. I also observed that tunning the parameters for LSTM (e.g the number of epochs and batch_size) resulted in better prediction.

# Interesting facts about the project
# When exploring the data, it was interesting to see how the stock prices of different companies changed due to the pandemic and how the technological companies stock prices bounced back more quickly than the other companies considered. It was also interesting to see how Pfizer stocks improved as the vaccine rollout began.

# Here are some major highlights from the data exploration section:

# 2019: Before the pandemic, most of the companies stocks were doing relatively well with Apple and Microsoft taking the lead and Pfizer trailing behind.
# 2020: On the onset of the pandemic around Spring, there was a fall in stock prices for all the companies, but afterwards the technology companies like Amazon, Apple, Microsoft and Google started to grow again. But companies like Pfizer, Ford and S&P 500 did not do very well especially Ford.
# 2021: As the vaccine rollout began and the lockdown began to be lifted, there was significant growth in the stock prices of Ford in particular given its very stock prices which was low in 2020 due to the pandemic. Companies like Google and Microsoft,S&P 500 also grew. Overall there was an improvement in the stock prices of all the companies we considered.
# Difficulties encountered
# Getting the data from yahoo fincance wasn't very obvious. After several research I was able to find an article that guided me on how to obtain the data.
# In the modelling part (particularly the LSTM), one would have to spend some time tuning the parameters and training it to get the best results.
